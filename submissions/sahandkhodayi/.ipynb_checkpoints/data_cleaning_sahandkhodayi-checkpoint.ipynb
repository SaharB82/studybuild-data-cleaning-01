# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel("First Dataset.xlsx")
df
# Out:
#     customer_id first_name gender   age     city         province signup_date  \
# 0          1001       Reza      F  19.0    Karaj           Alborz  2025-02-19
# 1          1002       Sina      M  53.0   Tehran           Tehran  2022-08-19
# 2          1003      Parsa      F  31.0   Shiraz             Fars  2023-06-20
# 3          1004       Sina      F  58.0  Mashhad         Khorasan  2021-11-08
# 4          1005      Kimia      M  28.0  Isfahan          Isfahan  2021-10-21
# ..          ...        ...    ...   ...      ...              ...         ...
# 56         1057     Maryam      M  58.0    Ahvaz        Khuzestan  2024-06-11
# 57         1058       Amir      F  47.0   Tehran           Tehran  2024-09-27
# 58         1059        Ali      F  57.0  Isfahan          Isfahan  2023-09-05
# 59         1060        Ali      M  63.0   Tabriz  East Azerbaijan  2021-04-27
# 60         1014       Reza      M  35.0   Tabriz  East Azerbaijan  2022-08-26
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         61 non-null     int64
#  1   first_name          61 non-null     str
#  2   gender              61 non-null     str
#  3   age                 60 non-null     float64
#  4   city                61 non-null     str
#  5   province            61 non-null     str
#  6   signup_date         61 non-null     str
#  7   membership_tier     61 non-null     str
#  8   purchase_count      61 non-null     int64
#  9   avg_order_value     61 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  61 non-null     int64
#  12  payment_method      61 non-null     str
#  13  device              61 non-null     str
#  14  discount_used       61 non-null     str
#  15  returned_items      61 non-null     int64
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'first_name', 'gender', 'age', 'city', 'province',
#        'signup_date', 'membership_tier', 'purchase_count', 'avg_order_value',
#        'total_spending', 'last_purchase_days', 'payment_method', 'device',
#        'discount_used', 'returned_items', 'satisfaction_score'],
#       dtype='str')

# %%
df.describe()
# Out:
#        customer_id         age  purchase_count  avg_order_value  \
# count    61.000000   60.000000       61.000000        61.000000
# mean   1030.229508   45.200000       17.606557       211.435738
# std      17.446483   19.167239       10.214824       130.113726
# min    1001.000000   19.000000        0.000000        27.630000
# 25%    1015.000000   31.750000       11.000000       108.190000
# 50%    1030.000000   45.000000       17.000000       161.330000
# 75%    1045.000000   58.000000       26.000000       323.320000
# max    1060.000000  145.000000       35.000000       449.810000
#
#        total_spending  last_purchase_days  returned_items  satisfaction_score
# count       60.000000           61.000000       61.000000            61.00000
# mean      3749.667333          196.934426        4.196721             3.00000
# std       4262.248522           97.892436        2.663454             1.42595
# min          0.000000            3.000000        0.000000             1.00000
# ...

# %%
df.nunique()
# Out:
# customer_id           60
# first_name            12
# gender                 2
# age                   34
# city                   8
# province               8
# signup_date           58
# membership_tier        4
# purchase_count        30
# avg_order_value       60
# total_spending        59
# last_purchase_days    54
# payment_method         3
# device                 3
# discount_used          2
# returned_items         9
# satisfaction_score     5
# dtype: int64

# %%
df.isna().sum()
# Out:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Length: 61, dtype: bool

# %%
df[df.duplicated()]
# Out:
#     customer_id first_name gender   age    city         province signup_date  \
# 60         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 60             VIP              31           108.19         3353.89
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 60                  97           Card  Android            No               5
#
#     satisfaction_score
# 60                   4

# %%
df[df.customer_id==1014] # dup Row
# Out:
#     customer_id first_name gender   age    city         province signup_date  \
# 13         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
# 60         1014       Reza      M  35.0  Tabriz  East Azerbaijan  2022-08-26
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 13             VIP              31           108.19         3353.89
# 60             VIP              31           108.19         3353.89
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 13                  97           Card  Android            No               5
# 60                  97           Card  Android            No               5
#
#     satisfaction_score
# 13                   4
# 60                   4

# %%
df = df.drop_duplicates() #removing dup

# %%
df
# Out:
#     customer_id first_name gender    age     city         province  \
# 0          1001       Reza      F   19.0    Karaj           Alborz
# 1          1002       Sina      M   53.0   Tehran           Tehran
# 2          1003      Parsa      F   31.0   Shiraz             Fars
# 3          1004       Sina      F   58.0  Mashhad         Khorasan
# 4          1005      Kimia      M   28.0  Isfahan          Isfahan
# 5          1006       Amir      F   58.0  Mashhad         Khorasan
# 6          1007       Reza      F   43.0    Rasht            Gilan
# 7          1008       Reza      F   23.0    Rasht            Gilan
# 8          1009      Kimia      M   61.0    Karaj           Alborz
# 9          1010      Arash      F  145.0    Karaj           Alborz
# 10         1011       Neda      F   41.0    Karaj           Alborz
# 11         1012      Arash      F   51.0  Mashhad         Khorasan
# 12         1013       Neda      F   39.0    Karaj           Alborz
# ...

# %%
df.dtypes
# Out:
# customer_id             int64
# first_name                str
# gender                    str
# age                   float64
# city                      str
# province                  str
# signup_date               str
# membership_tier           str
# purchase_count          int64
# avg_order_value       float64
# total_spending        float64
# last_purchase_days      int64
# payment_method            str
# device                    str
# discount_used             str
# returned_items          int64
# satisfaction_score      int64
# dtype: object

# %%
df["signup_date"] = pd.to_datetime(df["signup_date"], errors="coerce")
df.dtypes
# Out:
# customer_id                    int64
# first_name                       str
# gender                           str
# age                          float64
# city                             str
# province                         str
# signup_date           datetime64[us]
# membership_tier                  str
# purchase_count                 int64
# avg_order_value              float64
# total_spending               float64
# last_purchase_days             int64
# payment_method                   str
# device                           str
# discount_used                    str
# returned_items                 int64
# satisfaction_score             int64
# dtype: object

# %%
df.loc[df["age"] == 145, "age"] = 45
df["age"].mean() # new mean
# Out:
# np.float64(43.67796610169491)

# %%
df["age"].describe()
# Out:
# count    59.000000
# mean     43.677966
# std      14.065660
# min      19.000000
# 25%      31.500000
# 50%      45.000000
# 75%      58.000000
# max      65.000000
# Name: age, dtype: float64

# %%
df[df["total_spending"].isnull()]
# Out:
#     customer_id first_name gender   age    city province signup_date  \
# 39         1040       Amir      F  65.0  Tehran   Tehran  2021-11-02
#
#    membership_tier  purchase_count  avg_order_value  total_spending  \
# 39          Bronze              34            37.66             NaN
#
#     last_purchase_days payment_method   device discount_used  returned_items  \
# 39                 126           Card  Android           Yes               3
#
#     satisfaction_score
# 39                   2

# %%
df.loc[df["total_spending"].isnull(), "total_spending"] = 34 * 37.66

# %%
df[df["total_spending"].isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, gender, age, city, province, signup_date, membership_tier, purchase_count, avg_order_value, total_spending, last_purchase_days, payment_method, device, discount_used, returned_items, satisfaction_score]
# Index: []

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df["age"] = df["age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         60 non-null     int64
#  1   first_name          60 non-null     str
#  2   gender              60 non-null     str
#  3   age                 60 non-null     int64
#  4   city                60 non-null     str
#  5   province            60 non-null     str
#  6   signup_date         60 non-null     datetime64[us]
#  7   membership_tier     60 non-null     str
#  8   purchase_count      60 non-null     int64
#  9   avg_order_value     60 non-null     float64
#  10  total_spending      60 non-null     float64
#  11  last_purchase_days  60 non-null     int64
#  12  payment_method      60 non-null     str
#  13  device              60 non-null     str
#  14  discount_used       60 non-null     str
#  15  returned_items      60 non-null     int64
# ...

# %%
df.to_excel("cleaned_dataset_sahandkhodayi.xlsx", index=False)
